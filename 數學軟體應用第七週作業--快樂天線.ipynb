# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp
from sympy.abc import x

# %%
π = np.pi
x = np.linspace(-4*π, 4*π, 1000)
y = 1/np.cos(x)

# %%
plt.plot(x, y)

# %%
plt.scatter(x[y>0], y[y>0], c='#FF235A')
plt.plot(x,y)
